# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# ### In this notebook, data science tools and general Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data science.
# - List Commonly used libriaries for Data science.
# - Create a table of Data Science Tools.
# - Evaluate arithmetic expressions in Python.
# - Convert minutes to hours using Python.

# %% [markdown]
# #### Exercise 3

# %% [markdown]
# ### The most popular languages Data Scientists globally use include;
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# #### Exercise 4

# %% [markdown]
# ### The common libraries Data Scientists use include but are not limited to;
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# #### Exercise 5

# %% [markdown]
# |Data Science Tools|
# |---------|
# | Juypter Notebook |
# | RStudio |
# | Apache Zeppelin|

# %% [markdown]
# #### Exercise 6

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# #### Exercise 7

# %%
# This a simple arithmetic expression to mutiply then add integers.
(3*4) + 5
# Out:
# 17

# %% [markdown]
# #### Exercise 8

# %%
# This will convert 200 minutes to hours by diving by 60.

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# #### Exercise 9

# %% [markdown]
# ### Answer indicated in markdown cell after exercise 2

# %% [markdown]
# #### Exercise 10

# %% [markdown]
# ## Author
# Viola Kulabako
